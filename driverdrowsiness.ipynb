# %%
"DIGITAL IMAGE PROCESSING PROJECT"

# %%
#LIVE DETECTION 

import cv2
import dlib
import numpy as np
from scipy.spatial import distance as dist

def calculate_EAR(eye):
    """Calculate Eye Aspect Ratio"""
    A = dist.euclidean(eye[1], eye[5])
    B = dist.euclidean(eye[2], eye[4])
    C = dist.euclidean(eye[0], eye[3])
    EAR = (A + B) / (2.0 * C)
    return EAR

def calculate_percentage_eye_closure(eye):
    """Calculate percentage of eye closure"""
    vertical_distance = dist.euclidean(eye[1], eye[5]) + dist.euclidean(eye[2], eye[4])
    horizontal_distance = dist.euclidean(eye[0], eye[3])
    return (vertical_distance / (2.0 * horizontal_distance)) * 100

def calculate_MAR(mouth):
    """Calculate Mouth Aspect Ratio (MAR) for better yawn detection"""
    # Vertical distances
    V1 = dist.euclidean(mouth[3], mouth[9])    
    V2 = dist.euclidean(mouth[2], mouth[10])   
    V3 = dist.euclidean(mouth[1], mouth[11])   
    
    H = dist.euclidean(mouth[0], mouth[6])     
    
    # Calculate MAR
    MAR = (V1 + V2 + V3) / (3.0 * H)
    return MAR

def get_mouth_height_width_ratio(mouth):
    """
    Calculate the ratio of mouth height to width
    """
    mouth_top = min(point[1] for point in mouth[2:5])
    
    mouth_bottom = max(point[1] for point in mouth[8:11])
    
    mouth_left = min(point[0] for point in mouth[0:2])
      
    mouth_right = max(point[0] for point in mouth[6:8])
    
    height = dist.euclidean([0, mouth_top], [0, mouth_bottom])
    width = dist.euclidean([mouth_left, 0], [mouth_right, 0])
    
    if width > 0:
        return height / width
    return 0

# preprocessing functions 
def preprocess_image(frame):
    """Enhanced preprocessing pipeline that maintains face detection reliability"""
    if frame is None:
        return None
    
    original_height, original_width = frame.shape[:2]
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    gray = clahe.apply(gray)
    gray = cv2.fastNlMeansDenoising(gray, None, 10, 7, 21)
    kernel = np.array([[0, -1, 0],
                      [-1, 5, -1],
                      [0, -1, 0]])
    gray = cv2.filter2D(gray, -1, kernel)
    gray = cv2.GaussianBlur(gray, (3, 3), 0)
    gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX)
    return gray

def detect_face_at_scales(detector, frame):
    """Attempt face detection at different scales"""
    original_height, original_width = frame.shape[:2]
    scales = [1.0, 2.0, 0.5]
    
    for scale in scales:
        if scale == 1.0:
            rects = detector(frame, 0)
            if len(rects) > 0:
                return rects
        else:
            new_width = int(original_width * scale)
            new_height = int(original_height * scale)
            resized_frame = cv2.resize(frame, (new_width, new_height))
            rects = detector(resized_frame, 0)
            
            if len(rects) > 0:
                scaled_rects = dlib.rectangles()
                for rect in rects:
                    scaled_rect = dlib.rectangle(
                        int(rect.left() / scale),
                        int(rect.top() / scale),
                        int(rect.right() / scale),
                        int(rect.bottom() / scale)
                    )
                    scaled_rects.append(scaled_rect)
                return scaled_rects
    
    return dlib.rectangles()

def add_transparent_overlay(image, text_lines, start_x, start_y, padding=10):
    """Add semi-transparent background for text with overlay"""
    overlay = image.copy()
    max_width = 0
    total_height = 0
    line_heights = []
    
    for text, font_scale, _, thickness in text_lines:
        (text_width, text_height), _ = cv2.getTextSize(
            text, cv2.FONT_HERSHEY_SIMPLEX, font_scale, thickness
        )
        max_width = max(max_width, text_width)
        line_heights.append(text_height + 10)
        total_height += text_height + 10
    
    rect_x1 = start_x - padding
    rect_y1 = start_y - padding
    rect_x2 = start_x + max_width + padding
    rect_y2 = start_y + total_height + padding
    
    alpha = 0.5
    cv2.rectangle(overlay, (rect_x1, rect_y1), (rect_x2, rect_y2), (0, 0, 0), -1)
    cv2.addWeighted(overlay, alpha, image, 1 - alpha, 0, image)
    
    current_y = start_y
    for (text, font_scale, color, thickness), line_height in zip(text_lines, line_heights):
        cv2.putText(
            image, text, (start_x, current_y + line_height - 5),
            cv2.FONT_HERSHEY_SIMPLEX, font_scale, color, thickness
        )
        current_y += line_height

def main():
    try:
        detector = dlib.get_frontal_face_detector()
        predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
    except RuntimeError as e:
        print(f"Error loading facial landmark detector: {e}")
        print("Please ensure 'shape_predictor_68_face_landmarks.dat' is in the correct path")
        return

    cap = cv2.VideoCapture(0)
    
    if not cap.isOpened():
        print("Error: Could not open video capture device")
        return

    print("Starting video capture. Press 'q' to quit.")

    # Initialize variables for detection
    drowsy_frames = 0
    yawn_frames = 0
    DROWSY_THRESHOLD = 10
    YAWN_THRESHOLD = 5  
    MAR_THRESHOLD = 0.6  
    HEIGHT_WIDTH_RATIO_THRESHOLD = 0.5  

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Could not read frame")
            break

        original_frame = frame.copy()
        processed_frame = preprocess_image(frame)
        if processed_frame is None:
            continue
        

        faces = detect_face_at_scales(detector, processed_frame)
        faces_detected = len(faces) > 0

        if not faces_detected:
            cv2.putText(frame, "No face detected", (10, 30),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        else:
            for rect in faces:
                shape = predictor(processed_frame, rect)
                
                left_eye = np.array([(shape.part(i).x, shape.part(i).y) for i in range(36, 42)])
                right_eye = np.array([(shape.part(i).x, shape.part(i).y) for i in range(42, 48)])
                mouth = np.array([(shape.part(i).x, shape.part(i).y) for i in range(48, 68)])

                left_EAR = calculate_EAR(left_eye)
                right_EAR = calculate_EAR(right_eye)
                avg_EAR = (left_EAR + right_EAR) / 2.0
                
                left_eye_closure = calculate_percentage_eye_closure(left_eye)
                right_eye_closure = calculate_percentage_eye_closure(right_eye)
                
                mar = calculate_MAR(mouth)
                height_width_ratio = get_mouth_height_width_ratio(mouth)


                if mar > MAR_THRESHOLD and height_width_ratio > HEIGHT_WIDTH_RATIO_THRESHOLD:
                    yawn_frames += 1
                else:
                    yawn_frames = max(0, yawn_frames - 1)

                #  drowsiness status
                if avg_EAR < 0.25:
                    drowsy_frames += 1
                else:
                    drowsy_frames = max(0, drowsy_frames - 1)

                
                status = "DROWSY ALERT!" if drowsy_frames >= DROWSY_THRESHOLD else "Non drowsy"
                color = (0, 0, 255) if status == "DROWSY ALERT!" else (0, 255, 0)
                yawning_status = "YAWNING!" if yawn_frames >= YAWN_THRESHOLD else "Not Yawning"
                yawn_color = (0, 0, 255) if yawning_status == "YAWNING!" else (0, 255, 255)

                # Draw face rectangle
                x, y, w, h = rect.left(), rect.top(), rect.width(), rect.height()
                cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

                # Draw feature contours
                cv2.drawContours(frame, [cv2.convexHull(left_eye)], -1, (0, 255, 0), 1)
                cv2.drawContours(frame, [cv2.convexHull(right_eye)], -1, (0, 255, 0), 1)
                cv2.drawContours(frame, [cv2.convexHull(mouth)], -1, yawn_color, 1)

                # Create text lines with their properties
                text_lines = [
                    (f"Status: {status}", 0.7, color, 2),
                    (f"EAR: {avg_EAR:.2f}", 0.7, (255, 255, 255), 2),
                    (f"MAR: {mar:.2f}", 0.7, (255, 255, 255), 2),
                    (f"Yawn Status: {yawning_status}", 0.7, yawn_color, 2),
                    (f"Left Eye: {left_eye_closure:.1f}%", 0.7, (255, 255, 255), 1),
                    (f"Right Eye: {right_eye_closure:.1f}%", 0.7, (255, 255, 255), 1)
                ]
                
                add_transparent_overlay(frame, text_lines, 10, 10)

        cv2.imshow('Drowsiness Detection', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Starting video capture. Press 'q' to quit.

# %%
#Importing  the dataset from the file of our laptop and find  the drwosiness from the dataset which is already stored in the laptop storage and creating a 
#new sep folder for storing the processed images of the dataset

import cv2
import dlib
import numpy as np
from scipy.spatial import distance as dist
import os

def calculate_EAR(eye):
    """Calculate Eye Aspect Ratio"""
    A = dist.euclidean(eye[1], eye[5])
    B = dist.euclidean(eye[2], eye[4])
    C = dist.euclidean(eye[0], eye[3])
    EAR = (A + B) / (2.0 * C)
    return EAR

def calculate_percentage_eye_closure(eye):
    """Calculate percentage of eye closure"""
    vertical_distance = dist.euclidean(eye[1], eye[5]) + dist.euclidean(eye[2], eye[4])
    horizontal_distance = dist.euclidean(eye[0], eye[3])
    return (vertical_distance / (2.0 * horizontal_distance)) * 100

def calculate_yawn_distance(mouth):
    """Calculate vertical distance between lips"""
    if len(mouth) >= 58:
        upper_lip = mouth[51]
        lower_lip = mouth[57]
        return dist.euclidean(upper_lip, lower_lip)
    return 0

def preprocess_image(frame):
    """Enhanced preprocessing pipeline that maintains face detection reliability"""
    if frame is None:
        return None
    
    original_height, original_width = frame.shape[:2]
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    gray = clahe.apply(gray)
    
    gray = cv2.fastNlMeansDenoising(gray, None, 10, 7, 21)
    
    kernel = np.array([[0, -1, 0],
                      [-1, 5, -1],
                      [0, -1, 0]])
    gray = cv2.filter2D(gray, -1, kernel)
    
    gray = cv2.GaussianBlur(gray, (3, 3), 0)
    
    gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX)
    
    return gray

def detect_face_at_scales(detector, frame):
    """
    Attempt face detection at different scales by resizing the image instead of using dlib's upsample parameter.
    Returns the rectangles detected in the original image scale.
    """
    original_height, original_width = frame.shape[:2]
    scales = [1.0, 2.0, 0.5]  # Different scales to try
    
    for scale in scales:
        if scale == 1.0:
            rects = detector(frame, 0)  
            if len(rects) > 0:
                return rects
        else:
            new_width = int(original_width * scale)
            new_height = int(original_height * scale)
            resized_frame = cv2.resize(frame, (new_width, new_height))
            
            rects = detector(resized_frame, 0)
            
            if len(rects) > 0:
                scaled_rects = dlib.rectangles()
                for rect in rects:
                    scaled_rect = dlib.rectangle(
                        int(rect.left() / scale),
                        int(rect.top() / scale),
                        int(rect.right() / scale),
                        int(rect.bottom() / scale)
                    )
                    scaled_rects.append(scaled_rect)
                return scaled_rects
    
    return dlib.rectangles()   

def add_transparent_overlay(image, text_lines, start_x, start_y, padding=10):
    """
    Add semi-transparent background for text with overlay"""

        overlay = image.copy()
    
    max_width = 0
    total_height = 0
    line_heights = []
    
    for text, font_scale, _, thickness in text_lines:
        (text_width, text_height), _ = cv2.getTextSize(
            text, cv2.FONT_HERSHEY_SIMPLEX, font_scale, thickness
        )
        max_width = max(max_width, text_width)
        line_heights.append(text_height + 10)  
        total_height += text_height + 10
    
    
    rect_x1 = start_x - padding
    rect_y1 = start_y - padding
    rect_x2 = start_x + max_width + padding
    rect_y2 = start_y + total_height + padding
    
    alpha = 0.5  # Transparency factor (0 = fully transparent, 1 = fully opaque)
    cv2.rectangle(overlay, (rect_x1, rect_y1), (rect_x2, rect_y2), (0, 0, 0), -1)
    cv2.addWeighted(overlay, alpha, image, 1 - alpha, 0, image)
    
    current_y = start_y
    for (text, font_scale, color, thickness), line_height in zip(text_lines, line_heights):
        cv2.putText(
            image, text, (start_x, current_y + line_height - 5),
            cv2.FONT_HERSHEY_SIMPLEX, font_scale, color, thickness
        )
        current_y += line_height

def main():
    try:
        detector = dlib.get_frontal_face_detector()
        predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
    except RuntimeError as e:
        print(f"Error loading facial landmark detector: {e}")
        print("Please ensure 'shape_predictor_68_face_landmarks.dat' is in the correct path")
        return

    # Paths to dataset and output folders
    dataset_path = r"C:\Users\nandh\Downloads\Driver Drowsiness Dataset (DDD)\sample"
    output_path = r"C:\Users\nandh\Downloads\Driver Drowsiness Dataset (DDD)\output"

    # Create the output directory 
    os.makedirs(output_path, exist_ok=True)

    total_images = len([f for f in os.listdir(dataset_path) if f.endswith(('.jpg', '.jpeg', '.png'))])
    processed_images = 0

    for filename in os.listdir(dataset_path):
        if filename.endswith(('.jpg', '.jpeg', '.png')):
            processed_images += 1
            print(f"Processing image {processed_images}/{total_images}: {filename}")
            
            image_path = os.path.join(dataset_path, filename)
            frame = cv2.imread(image_path)

            if frame is None:
                print(f"Error: Could not load the image {filename}")
                continue

            original_frame = frame.copy()
            
            processed_frame = preprocess_image(frame)
            if processed_frame is None:
                print(f"Error: Failed to preprocess {filename}")
                continue

            faces = detect_face_at_scales(detector, processed_frame)
            faces_detected = len(faces) > 0

            if not faces_detected:
                print(f"No face detected in {filename}")
                debug_image = np.hstack((original_frame, cv2.cvtColor(processed_frame, cv2.COLOR_GRAY2BGR)))
                cv2.imwrite(os.path.join(output_path, f"debug_{filename}"), debug_image)
                continue

            for rect in faces:
                shape = predictor(processed_frame, rect)
                
                left_eye = np.array([(shape.part(i).x, shape.part(i).y) for i in range(36, 42)])
                right_eye = np.array([(shape.part(i).x, shape.part(i).y) for i in range(42, 48)])
                mouth = np.array([(shape.part(i).x, shape.part(i).y) for i in range(48, 68)])

                
                left_EAR = calculate_EAR(left_eye)
                right_EAR = calculate_EAR(right_eye)
                avg_EAR = (left_EAR + right_EAR) / 2.0
                
                left_eye_closure = calculate_percentage_eye_closure(left_eye)
                right_eye_closure = calculate_percentage_eye_closure(right_eye)
                yawn_distance = calculate_yawn_distance(mouth)

                # Determine status
                status = "Drowsy!" if avg_EAR < 0.25 else "Not drowsy"
                color = (0, 0, 255) if status == "Drowsy!" else (0, 255, 0)
                yawning_status = "Yawning!" if yawn_distance > 20 else "Not Yawning"

                
                x, y, w, h = rect.left(), rect.top(), rect.width(), rect.height()
                cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

                
                cv2.drawContours(frame, [cv2.convexHull(left_eye)], -1, (0, 255, 0), 1)
                cv2.drawContours(frame, [cv2.convexHull(right_eye)], -1, (0, 255, 0), 1)
                cv2.drawContours(frame, [cv2.convexHull(mouth)], -1, (0, 255, 255), 1)

                text_lines = [
                    (f"Status: {status}", 0.7, color, 2),
                    (f"EAR: {avg_EAR:.2f}", 0.7, (255, 255, 255), 2),
                    (f"Left Eye: {left_eye_closure:.1f}%", 0.7, (255, 255, 255), 1),
                    (f"Right Eye: {right_eye_closure:.1f}%", 0.7, (255, 255, 255), 1),
                    (f"{yawning_status}", 0.7, (0, 255, 255), 1)
                ]
                
                add_transparent_overlay(frame, text_lines, 10, 10)

            output_image_path = os.path.join(output_path, filename)
            cv2.imwrite(output_image_path, frame)
            
            print(f"Results for {filename}:")
            print(f"- Status: {status}")
            print(f"- Average EAR: {avg_EAR:.2f}")
            print(f"- Eye Closure: L={left_eye_closure:.1f}%, R={right_eye_closure:.1f}%")
            print(f"- Yawning Status: {yawning_status}")
            print("-" * 50)

    print("\nProcessing complete!")
    print(f"Processed {processed_images} images")

if __name__ == "__main__":
    main()
# Out:
# Processing image 1/185: A1183.png
# Results for A1183.png:
# - Status: Drowsy!
# - Average EAR: 0.11
# - Eye Closure: L=10.8%, R=11.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 2/185: A1184.png
# Results for A1184.png:
# - Status: Drowsy!
# - Average EAR: 0.16
# - Eye Closure: L=15.8%, R=15.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 3/185: A1185.png
# Results for A1185.png:
# - Status: Drowsy!
# - Average EAR: 0.19
# - Eye Closure: L=20.6%, R=17.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 4/185: A1186.png
# Results for A1186.png:
# - Status: Drowsy!
# - Average EAR: 0.13
# - Eye Closure: L=13.3%, R=12.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 5/185: A1187.png
# Results for A1187.png:
# - Status: Drowsy!
# - Average EAR: 0.18
# - Eye Closure: L=16.8%, R=19.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 6/185: A1195.png
# Results for A1195.png:
# - Status: Drowsy!
# - Average EAR: 0.13
# - Eye Closure: L=14.3%, R=12.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 7/185: A1196.png
# Results for A1196.png:
# - Status: Drowsy!
# - Average EAR: 0.14
# - Eye Closure: L=14.3%, R=13.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 8/185: A1197.png
# Results for A1197.png:
# - Status: Drowsy!
# - Average EAR: 0.17
# - Eye Closure: L=16.3%, R=17.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 9/185: A1198.png
# Results for A1198.png:
# - Status: Drowsy!
# - Average EAR: 0.18
# - Eye Closure: L=18.2%, R=18.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 10/185: A1199.png
# Results for A1199.png:
# - Status: Drowsy!
# - Average EAR: 0.16
# - Eye Closure: L=17.5%, R=15.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 11/185: B0271.png
# Results for B0271.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=20.2%, R=20.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 12/185: B0272.png
# Results for B0272.png:
# - Status: Drowsy!
# - Average EAR: 0.22
# - Eye Closure: L=22.8%, R=21.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 13/185: B0273.png
# Results for B0273.png:
# - Status: Drowsy!
# - Average EAR: 0.10
# - Eye Closure: L=10.1%, R=10.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 14/185: B0274.png
# Results for B0274.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=20.2%, R=19.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 15/185: B0275.png
# Results for B0275.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=21.5%, R=19.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 16/185: B0276.png
# Results for B0276.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=20.1%, R=20.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 17/185: B0277.png
# Results for B0277.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=19.9%, R=19.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 18/185: B0283.png
# Results for B0283.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=20.4%, R=19.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 19/185: B0284.png
# Results for B0284.png:
# - Status: Drowsy!
# - Average EAR: 0.07
# - Eye Closure: L=9.1%, R=4.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 20/185: B0285.png
# Results for B0285.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=19.9%, R=19.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 21/185: B0286.png
# Results for B0286.png:
# - Status: Drowsy!
# - Average EAR: 0.08
# - Eye Closure: L=8.7%, R=7.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 22/185: B0287.png
# Results for B0287.png:
# - Status: Drowsy!
# - Average EAR: 0.13
# - Eye Closure: L=14.4%, R=11.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 23/185: B0290.png
# Results for B0290.png:
# - Status: Drowsy!
# - Average EAR: 0.16
# - Eye Closure: L=17.2%, R=15.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 24/185: B0291.png
# Results for B0291.png:
# - Status: Drowsy!
# - Average EAR: 0.15
# - Eye Closure: L=16.1%, R=14.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 25/185: C0003.png
# Results for C0003.png:
# - Status: Not drowsy
# - Average EAR: 0.41
# - Eye Closure: L=40.3%, R=41.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 26/185: C0004.png
# Results for C0004.png:
# - Status: Drowsy!
# - Average EAR: 0.23
# - Eye Closure: L=24.2%, R=21.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 27/185: C0005.png
# Results for C0005.png:
# - Status: Not drowsy
# - Average EAR: 0.46
# - Eye Closure: L=44.8%, R=47.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 28/185: C0006.png
# Results for C0006.png:
# - Status: Not drowsy
# - Average EAR: 0.44
# - Eye Closure: L=44.3%, R=44.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 29/185: drowsiness.jpg
# Results for drowsiness.jpg:
# - Status: Drowsy!
# - Average EAR: 0.22
# - Eye Closure: L=20.8%, R=23.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 30/185: E0714.png
# Results for E0714.png:
# - Status: Not drowsy
# - Average EAR: 0.27
# - Eye Closure: L=27.0%, R=27.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 31/185: E0715.png
# No face detected in E0715.png
# Processing image 32/185: E0716.png
# No face detected in E0716.png
# Processing image 33/185: E0717.png
# No face detected in E0717.png
# Processing image 34/185: E0719.png
# No face detected in E0719.png
# Processing image 35/185: E0727.png
# No face detected in E0727.png
# Processing image 36/185: E0728.png
# No face detected in E0728.png
# Processing image 37/185: E0729.png
# Results for E0729.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=20.7%, R=21.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 38/185: E0730.png
# Results for E0730.png:
# - Status: Not drowsy
# - Average EAR: 0.33
# - Eye Closure: L=32.2%, R=33.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 39/185: E0731.png
# No face detected in E0731.png
# Processing image 40/185: E0751.png
# Results for E0751.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=21.0%, R=18.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 41/185: E0752.png
# No face detected in E0752.png
# Processing image 42/185: E0763.png
# No face detected in E0763.png
# Processing image 43/185: E0764.png
# No face detected in E0764.png
# Processing image 44/185: E0776.png
# No face detected in E0776.png
# Processing image 45/185: E0777.png
# No face detected in E0777.png
# Processing image 46/185: E0788.png
# Results for E0788.png:
# - Status: Not drowsy
# - Average EAR: 0.37
# - Eye Closure: L=37.3%, R=37.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 47/185: E0789.png
# Results for E0789.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=21.1%, R=20.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 48/185: H0081.png
# Results for H0081.png:
# - Status: Not drowsy
# - Average EAR: 0.27
# - Eye Closure: L=26.6%, R=28.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 49/185: H0082.png
# Results for H0082.png:
# - Status: Drowsy!
# - Average EAR: 0.23
# - Eye Closure: L=24.3%, R=22.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 50/185: H0083.png
# Results for H0083.png:
# - Status: Not drowsy
# - Average EAR: 0.29
# - Eye Closure: L=27.5%, R=31.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 51/185: H0084.png
# Results for H0084.png:
# - Status: Not drowsy
# - Average EAR: 0.32
# - Eye Closure: L=31.3%, R=33.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 52/185: H0085.png
# Results for H0085.png:
# - Status: Not drowsy
# - Average EAR: 0.29
# - Eye Closure: L=28.4%, R=28.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 53/185: H0093.png
# Results for H0093.png:
# - Status: Not drowsy
# - Average EAR: 0.29
# - Eye Closure: L=28.5%, R=30.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 54/185: H0094.png
# Results for H0094.png:
# - Status: Not drowsy
# - Average EAR: 0.30
# - Eye Closure: L=29.7%, R=31.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 55/185: H0095.png
# Results for H0095.png:
# - Status: Not drowsy
# - Average EAR: 0.37
# - Eye Closure: L=36.7%, R=37.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 56/185: H0096.png
# Results for H0096.png:
# - Status: Not drowsy
# - Average EAR: 0.35
# - Eye Closure: L=33.9%, R=36.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 57/185: H0097.png
# Results for H0097.png:
# - Status: Not drowsy
# - Average EAR: 0.33
# - Eye Closure: L=33.4%, R=32.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 58/185: I0115.png
# Results for I0115.png:
# - Status: Drowsy!
# - Average EAR: 0.10
# - Eye Closure: L=11.1%, R=9.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 59/185: I0116.png
# Results for I0116.png:
# - Status: Drowsy!
# - Average EAR: 0.09
# - Eye Closure: L=9.0%, R=8.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 60/185: I0123.png
# Results for I0123.png:
# - Status: Drowsy!
# - Average EAR: 0.11
# - Eye Closure: L=11.4%, R=11.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 61/185: I0124.png
# Results for I0124.png:
# - Status: Drowsy!
# - Average EAR: 0.13
# - Eye Closure: L=13.4%, R=12.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 62/185: I0136.png
# Results for I0136.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=20.7%, R=20.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 63/185: I0137.png
# Results for I0137.png:
# - Status: Drowsy!
# - Average EAR: 0.22
# - Eye Closure: L=22.9%, R=21.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 64/185: I0138.png
# Results for I0138.png:
# - Status: Drowsy!
# - Average EAR: 0.23
# - Eye Closure: L=22.9%, R=22.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 65/185: I0139.png
# Results for I0139.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=20.6%, R=19.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 66/185: I0969.png
# Results for I0969.png:
# - Status: Drowsy!
# - Average EAR: 0.23
# - Eye Closure: L=23.6%, R=22.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 67/185: I0970.png
# Results for I0970.png:
# - Status: Drowsy!
# - Average EAR: 0.15
# - Eye Closure: L=14.7%, R=15.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 68/185: I0971.png
# Results for I0971.png:
# - Status: Drowsy!
# - Average EAR: 0.18
# - Eye Closure: L=18.6%, R=17.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 69/185: I0972.png
# Results for I0972.png:
# - Status: Drowsy!
# - Average EAR: 0.19
# - Eye Closure: L=18.9%, R=18.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 70/185: I0982.png
# Results for I0982.png:
# - Status: Drowsy!
# - Average EAR: 0.19
# - Eye Closure: L=18.5%, R=20.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 71/185: I0983.png
# Results for I0983.png:
# - Status: Drowsy!
# - Average EAR: 0.09
# - Eye Closure: L=8.8%, R=9.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 72/185: I0984.png
# Results for I0984.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=20.9%, R=19.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 73/185: I0985.png
# Results for I0985.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=20.9%, R=20.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 74/185: J0145.png
# Results for J0145.png:
# - Status: Drowsy!
# - Average EAR: 0.16
# - Eye Closure: L=17.1%, R=15.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 75/185: J0146.png
# Results for J0146.png:
# - Status: Drowsy!
# - Average EAR: 0.11
# - Eye Closure: L=10.2%, R=12.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 76/185: J0147.png
# Results for J0147.png:
# - Status: Drowsy!
# - Average EAR: 0.09
# - Eye Closure: L=8.3%, R=10.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 77/185: J0148.png
# Results for J0148.png:
# - Status: Drowsy!
# - Average EAR: 0.18
# - Eye Closure: L=17.5%, R=18.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 78/185: K0534.png
# Results for K0534.png:
# - Status: Not drowsy
# - Average EAR: 0.26
# - Eye Closure: L=25.0%, R=26.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 79/185: K0535.png
# Results for K0535.png:
# - Status: Drowsy!
# - Average EAR: 0.23
# - Eye Closure: L=23.3%, R=23.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 80/185: K0536.png
# Results for K0536.png:
# - Status: Not drowsy
# - Average EAR: 0.26
# - Eye Closure: L=25.1%, R=27.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 81/185: K0537.png
# Results for K0537.png:
# - Status: Not drowsy
# - Average EAR: 0.32
# - Eye Closure: L=32.7%, R=31.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 82/185: K0538.png
# Results for K0538.png:
# - Status: Not drowsy
# - Average EAR: 0.27
# - Eye Closure: L=25.9%, R=27.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 83/185: K0539.png
# Results for K0539.png:
# - Status: Not drowsy
# - Average EAR: 0.29
# - Eye Closure: L=27.7%, R=30.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 84/185: K0540.png
# Results for K0540.png:
# - Status: Drowsy!
# - Average EAR: 0.25
# - Eye Closure: L=23.4%, R=25.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 85/185: K0541.png
# Results for K0541.png:
# - Status: Drowsy!
# - Average EAR: 0.15
# - Eye Closure: L=14.6%, R=14.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 86/185: K0546.png
# Results for K0546.png:
# - Status: Drowsy!
# - Average EAR: 0.24
# - Eye Closure: L=22.4%, R=25.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 87/185: K0547.png
# Results for K0547.png:
# - Status: Drowsy!
# - Average EAR: 0.18
# - Eye Closure: L=16.9%, R=18.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 88/185: K0548.png
# Results for K0548.png:
# - Status: Not drowsy
# - Average EAR: 0.29
# - Eye Closure: L=28.9%, R=28.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 89/185: K0549.png
# Results for K0549.png:
# - Status: Drowsy!
# - Average EAR: 0.16
# - Eye Closure: L=16.0%, R=15.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 90/185: K0550.png
# Results for K0550.png:
# - Status: Drowsy!
# - Average EAR: 0.18
# - Eye Closure: L=18.0%, R=17.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 91/185: K0551.png
# Results for K0551.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=22.4%, R=20.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 92/185: K0552.png
# Results for K0552.png:
# - Status: Not drowsy
# - Average EAR: 0.31
# - Eye Closure: L=31.5%, R=30.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 93/185: K0553.png
# Results for K0553.png:
# - Status: Drowsy!
# - Average EAR: 0.19
# - Eye Closure: L=19.0%, R=19.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 94/185: L0390.png
# Results for L0390.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=21.7%, R=19.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 95/185: L0391.png
# Results for L0391.png:
# - Status: Drowsy!
# - Average EAR: 0.22
# - Eye Closure: L=23.3%, R=20.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 96/185: L0392.png
# Results for L0392.png:
# - Status: Drowsy!
# - Average EAR: 0.22
# - Eye Closure: L=22.4%, R=21.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 97/185: L0393.png
# Results for L0393.png:
# - Status: Drowsy!
# - Average EAR: 0.22
# - Eye Closure: L=23.3%, R=20.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 98/185: L0402.png
# Results for L0402.png:
# - Status: Drowsy!
# - Average EAR: 0.17
# - Eye Closure: L=18.3%, R=16.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 99/185: L0403.png
# Results for L0403.png:
# - Status: Drowsy!
# - Average EAR: 0.19
# - Eye Closure: L=20.1%, R=17.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 100/185: L0404.png
# Results for L0404.png:
# - Status: Drowsy!
# - Average EAR: 0.18
# - Eye Closure: L=20.0%, R=16.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 101/185: L0405.png
# Results for L0405.png:
# - Status: Drowsy!
# - Average EAR: 0.18
# - Eye Closure: L=19.0%, R=16.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 102/185: L0490.png
# Results for L0490.png:
# - Status: Drowsy!
# - Average EAR: 0.19
# - Eye Closure: L=19.3%, R=19.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 103/185: L0491.png
# Results for L0491.png:
# - Status: Drowsy!
# - Average EAR: 0.22
# - Eye Closure: L=23.3%, R=21.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 104/185: L0492.png
# Results for L0492.png:
# - Status: Drowsy!
# - Average EAR: 0.18
# - Eye Closure: L=18.7%, R=16.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 105/185: L0493.png
# Results for L0493.png:
# - Status: Drowsy!
# - Average EAR: 0.17
# - Eye Closure: L=17.7%, R=16.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 106/185: L0494.png
# Results for L0494.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=21.0%, R=20.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 107/185: L0520.png
# Results for L0520.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=22.7%, R=20.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 108/185: L0521.png
# Results for L0521.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=22.7%, R=20.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 109/185: L0522.png
# Results for L0522.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=21.1%, R=19.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 110/185: L0523.png
# Results for L0523.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=23.4%, R=19.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 111/185: L0524.png
# Results for L0524.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=22.6%, R=19.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 112/185: L0537.png
# Results for L0537.png:
# - Status: Drowsy!
# - Average EAR: 0.23
# - Eye Closure: L=22.2%, R=24.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 113/185: L0538.png
# Results for L0538.png:
# - Status: Drowsy!
# - Average EAR: 0.19
# - Eye Closure: L=20.6%, R=18.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 114/185: L0539.png
# Results for L0539.png:
# - Status: Drowsy!
# - Average EAR: 0.23
# - Eye Closure: L=23.8%, R=21.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 115/185: L0540.png
# Results for L0540.png:
# - Status: Drowsy!
# - Average EAR: 0.22
# - Eye Closure: L=22.9%, R=21.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 116/185: L0541.png
# Results for L0541.png:
# - Status: Drowsy!
# - Average EAR: 0.20
# - Eye Closure: L=20.9%, R=18.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 117/185: M0339.png
# Results for M0339.png:
# - Status: Drowsy!
# - Average EAR: 0.12
# - Eye Closure: L=12.9%, R=11.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 118/185: M0340.png
# Results for M0340.png:
# - Status: Drowsy!
# - Average EAR: 0.14
# - Eye Closure: L=15.7%, R=12.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 119/185: M0341.png
# Results for M0341.png:
# - Status: Drowsy!
# - Average EAR: 0.11
# - Eye Closure: L=11.6%, R=9.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 120/185: M0351.png
# Results for M0351.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=22.9%, R=18.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 121/185: M0352.png
# Results for M0352.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=21.7%, R=20.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 122/185: M0353.png
# Results for M0353.png:
# - Status: Drowsy!
# - Average EAR: 0.21
# - Eye Closure: L=21.6%, R=20.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 123/185: N1159.png
# No face detected in N1159.png
# Processing image 124/185: N1160.png
# No face detected in N1160.png
# Processing image 125/185: N1161.png
# Results for N1161.png:
# - Status: Drowsy!
# - Average EAR: 0.08
# - Eye Closure: L=5.3%, R=9.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 126/185: N1162.png
# No face detected in N1162.png
# Processing image 127/185: N1163.png
# No face detected in N1163.png
# Processing image 128/185: O0001.png
# Results for O0001.png:
# - Status: Not drowsy
# - Average EAR: 0.25
# - Eye Closure: L=26.6%, R=23.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 129/185: O0002.png
# Results for O0002.png:
# - Status: Drowsy!
# - Average EAR: 0.23
# - Eye Closure: L=22.9%, R=22.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 130/185: O0003.png
# Results for O0003.png:
# - Status: Not drowsy
# - Average EAR: 0.26
# - Eye Closure: L=26.8%, R=25.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 131/185: O0004.png
# Results for O0004.png:
# - Status: Drowsy!
# - Average EAR: 0.16
# - Eye Closure: L=16.8%, R=15.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 132/185: O0005.png
# Results for O0005.png:
# - Status: Not drowsy
# - Average EAR: 0.27
# - Eye Closure: L=27.2%, R=26.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 133/185: P0066.png
# Results for P0066.png:
# - Status: Drowsy!
# - Average EAR: 0.16
# - Eye Closure: L=16.6%, R=15.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 134/185: P0067.png
# Results for P0067.png:
# - Status: Drowsy!
# - Average EAR: 0.17
# - Eye Closure: L=18.5%, R=14.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 135/185: P0068.png
# Results for P0068.png:
# - Status: Drowsy!
# - Average EAR: 0.14
# - Eye Closure: L=15.4%, R=13.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 136/185: P0069.png
# Results for P0069.png:
# - Status: Drowsy!
# - Average EAR: 0.10
# - Eye Closure: L=11.5%, R=8.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 137/185: P0070.png
# Results for P0070.png:
# - Status: Drowsy!
# - Average EAR: 0.12
# - Eye Closure: L=13.4%, R=9.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 138/185: P0071.png
# Results for P0071.png:
# - Status: Drowsy!
# - Average EAR: 0.18
# - Eye Closure: L=18.6%, R=16.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 139/185: ZA0731.png
# Results for ZA0731.png:
# - Status: Drowsy!
# - Average EAR: 0.11
# - Eye Closure: L=10.3%, R=11.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 140/185: ZA0732.png
# Results for ZA0732.png:
# - Status: Drowsy!
# - Average EAR: 0.09
# - Eye Closure: L=8.2%, R=8.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 141/185: ZA0733.png
# Results for ZA0733.png:
# - Status: Drowsy!
# - Average EAR: 0.08
# - Eye Closure: L=7.5%, R=9.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 142/185: ZA0734.png
# Results for ZA0734.png:
# - Status: Drowsy!
# - Average EAR: 0.07
# - Eye Closure: L=5.6%, R=8.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 143/185: ZA0735.png
# Results for ZA0735.png:
# - Status: Drowsy!
# - Average EAR: 0.06
# - Eye Closure: L=5.2%, R=7.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 144/185: ZA0736.png
# Results for ZA0736.png:
# - Status: Drowsy!
# - Average EAR: 0.15
# - Eye Closure: L=14.9%, R=14.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 145/185: ZA0743.png
# Results for ZA0743.png:
# - Status: Drowsy!
# - Average EAR: 0.16
# - Eye Closure: L=14.9%, R=16.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 146/185: ZA0744.png
# Results for ZA0744.png:
# - Status: Drowsy!
# - Average EAR: 0.15
# - Eye Closure: L=15.7%, R=15.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 147/185: ZA0745.png
# Results for ZA0745.png:
# - Status: Drowsy!
# - Average EAR: 0.17
# - Eye Closure: L=15.3%, R=18.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 148/185: ZA0746.png
# Results for ZA0746.png:
# - Status: Drowsy!
# - Average EAR: 0.14
# - Eye Closure: L=13.3%, R=15.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 149/185: ZA0747.png
# Results for ZA0747.png:
# - Status: Drowsy!
# - Average EAR: 0.17
# - Eye Closure: L=17.2%, R=16.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 150/185: ZA0748.png
# Results for ZA0748.png:
# - Status: Drowsy!
# - Average EAR: 0.19
# - Eye Closure: L=18.2%, R=20.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 151/185: ZC0700.png
# Results for ZC0700.png:
# - Status: Not drowsy
# - Average EAR: 0.40
# - Eye Closure: L=39.3%, R=40.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 152/185: ZC0701.png
# Results for ZC0701.png:
# - Status: Not drowsy
# - Average EAR: 0.42
# - Eye Closure: L=38.1%, R=45.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 153/185: ZC0702.png
# Results for ZC0702.png:
# - Status: Not drowsy
# - Average EAR: 0.41
# - Eye Closure: L=39.5%, R=43.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 154/185: ZC0705.png
# Results for ZC0705.png:
# - Status: Not drowsy
# - Average EAR: 0.38
# - Eye Closure: L=34.9%, R=41.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 155/185: ZC0706.png
# Results for ZC0706.png:
# - Status: Not drowsy
# - Average EAR: 0.40
# - Eye Closure: L=37.6%, R=41.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 156/185: ZC0707.png
# Results for ZC0707.png:
# - Status: Not drowsy
# - Average EAR: 0.39
# - Eye Closure: L=35.9%, R=43.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 157/185: ZC0708.png
# Results for ZC0708.png:
# - Status: Not drowsy
# - Average EAR: 0.42
# - Eye Closure: L=39.2%, R=45.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 158/185: ZC0709.png
# Results for ZC0709.png:
# - Status: Not drowsy
# - Average EAR: 0.38
# - Eye Closure: L=36.1%, R=40.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 159/185: ZC0710.png
# Results for ZC0710.png:
# - Status: Not drowsy
# - Average EAR: 0.39
# - Eye Closure: L=37.7%, R=40.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 160/185: ZC0711.png
# Results for ZC0711.png:
# - Status: Not drowsy
# - Average EAR: 0.43
# - Eye Closure: L=40.7%, R=45.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 161/185: ZC0712.png
# Results for ZC0712.png:
# - Status: Not drowsy
# - Average EAR: 0.40
# - Eye Closure: L=37.1%, R=43.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 162/185: ZC0713.png
# Results for ZC0713.png:
# - Status: Not drowsy
# - Average EAR: 0.40
# - Eye Closure: L=37.7%, R=41.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 163/185: ZC0714.png
# Results for ZC0714.png:
# - Status: Drowsy!
# - Average EAR: 0.23
# - Eye Closure: L=21.9%, R=23.3%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 164/185: ZC0717.png
# Results for ZC0717.png:
# - Status: Not drowsy
# - Average EAR: 0.38
# - Eye Closure: L=38.1%, R=38.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 165/185: ZC0718.png
# Results for ZC0718.png:
# - Status: Not drowsy
# - Average EAR: 0.40
# - Eye Closure: L=36.9%, R=43.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 166/185: ZC0719.png
# Results for ZC0719.png:
# - Status: Not drowsy
# - Average EAR: 0.38
# - Eye Closure: L=36.4%, R=40.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 167/185: ZC0748.png
# Results for ZC0748.png:
# - Status: Not drowsy
# - Average EAR: 0.30
# - Eye Closure: L=29.2%, R=30.2%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 168/185: ZC0749.png
# Results for ZC0749.png:
# - Status: Not drowsy
# - Average EAR: 0.36
# - Eye Closure: L=33.4%, R=37.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 169/185: ZC0763.png
# Results for ZC0763.png:
# - Status: Not drowsy
# - Average EAR: 0.39
# - Eye Closure: L=37.1%, R=41.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 170/185: ZC0764.png
# Results for ZC0764.png:
# - Status: Not drowsy
# - Average EAR: 0.41
# - Eye Closure: L=37.6%, R=44.8%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 171/185: ZC0765.png
# Results for ZC0765.png:
# - Status: Drowsy!
# - Average EAR: 0.23
# - Eye Closure: L=20.1%, R=25.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 172/185: ZC0766.png
# Results for ZC0766.png:
# - Status: Not drowsy
# - Average EAR: 0.30
# - Eye Closure: L=29.5%, R=31.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 173/185: ZC0770.png
# Results for ZC0770.png:
# - Status: Drowsy!
# - Average EAR: 0.19
# - Eye Closure: L=17.2%, R=20.0%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 174/185: zc1269.png
# Results for zc1269.png:
# - Status: Not drowsy
# - Average EAR: 0.40
# - Eye Closure: L=40.0%, R=39.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 175/185: zc1270.png
# Results for zc1270.png:
# - Status: Not drowsy
# - Average EAR: 0.34
# - Eye Closure: L=36.3%, R=31.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 176/185: zc1273.png
# Results for zc1273.png:
# - Status: Not drowsy
# - Average EAR: 0.41
# - Eye Closure: L=41.3%, R=41.1%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 177/185: zc1274.png
# Results for zc1274.png:
# - Status: Not drowsy
# - Average EAR: 0.42
# - Eye Closure: L=43.8%, R=40.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 178/185: zc1275.png
# Results for zc1275.png:
# - Status: Not drowsy
# - Average EAR: 0.40
# - Eye Closure: L=40.0%, R=40.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 179/185: zc1276.png
# Results for zc1276.png:
# - Status: Not drowsy
# - Average EAR: 0.40
# - Eye Closure: L=41.2%, R=39.4%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 180/185: zc1277.png
# Results for zc1277.png:
# - Status: Not drowsy
# - Average EAR: 0.40
# - Eye Closure: L=41.4%, R=39.5%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 181/185: zc1280.png
# Results for zc1280.png:
# - Status: Not drowsy
# - Average EAR: 0.41
# - Eye Closure: L=41.0%, R=40.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 182/185: zc1281.png
# Results for zc1281.png:
# - Status: Not drowsy
# - Average EAR: 0.41
# - Eye Closure: L=41.0%, R=40.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 183/185: zc1282.png
# Results for zc1282.png:
# - Status: Not drowsy
# - Average EAR: 0.38
# - Eye Closure: L=38.4%, R=37.9%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 184/185: zc1283.png
# Results for zc1283.png:
# - Status: Not drowsy
# - Average EAR: 0.40
# - Eye Closure: L=40.1%, R=39.7%
# - Yawning Status: Not Yawning
# --------------------------------------------------
# Processing image 185/185: zc1284.png
# Results for zc1284.png:
# - Status: Not drowsy
# - Average EAR: 0.41
# - Eye Closure: L=40.6%, R=40.6%
# - Yawning Status: Not Yawning
# --------------------------------------------------
#
# Processing complete!
# Processed 185 images
